# %%
"""
# !pip install PyMuPDF
# !pip install pdf2image
# !pip install farm-haystack[ocr]
# !pip install langdetect
# xpdf yüklendi pathi ayarlandı.
# !pip install elasticsearch==7.15.1
# !pip install fuzzywuzzy
"""
# Out:
# '\n!pip install PyMuPDF\n!pip install pdf2image\n!pip install farm-haystack[ocr]\n!pip install langdetect\n# xpdf yüklendi pathi ayarlandı.\n'

# %% [markdown]
# # Test DocumentPipeline

# %%
from utils.documentPipeline import DocumentPipeline

DocumentPipeline = DocumentPipeline(valid_languages=["tr","en"], remove_numeric_tables=True)

out = DocumentPipeline.process_txt(["testfile.pdf"])

# out[0]["documents"]
# out[0]["file_paths"]
# Out:
# OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# WARNING:haystack.nodes.answer_generator.openai:OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# ...
# Preprocessing:   0%|          | 0/1 [00:00<?, ?docs/s]
# WARNING:haystack.nodes.preprocessor.preprocessor:We found one or more sentences whose word count is higher than the split length.

# %%
out
# Out:
# [{'documents': [<Document: {'content': 'TÜRKİYE TARIM SEKTÖRÜ RAPORU 2013 TÜRKİYE TARIM SEKTÖRÜ RAPORU 2013 Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr II Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr ISBN: 978-605-137-388-1 TOBB Yayın No: 2014/230 TOBB yayınları için ayrıntılı bilgi Yayın Müdürlüğünden alınabilir. Tel : (0312) 218 20 00 Faks : (0312) 218 20 64 internet : www.tobb.org.tr TOBB yayınlarına tam metin ve ücretsiz olarak internetten ulaşabilirsiniz. Basım: Afşaroğlu Matbaası (0312) 384 54 88 Kazım Karabekir Cad.', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0, 'language': 'tr'}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'ea3b6f3ed7074f07cb3a1fba049c4693'}>,
# ...

# %%
InMemoryDocumentStore(KeywordDocumentStore)

# %% [markdown]
# # Test ElasticClient

# %%
from utils.elasticClient import ElasticClient

# Replace with your actual host, port, username, and password
host = "elastic-ede4ac.es.us-central1.gcp.cloud.es.io"
port = 9243
username = "elastic"
password = "iQR2A4PZiIsE0XO7BZ11hH5R"

# Initialize the ElasticClient
client = ElasticClient(host=host, port=port, username=username, password=password)

# Test the connection
print("Testing connection:", client.test_connection())
# Out:
# Testing connection: True

# %%
# Before do anything haystack related, get document store object from elastic client.

# document_store = client.get_document_store()
# document_store.write_documents(out[0]["documents"])

# %%
# search is not hs related, so no need to get document store.
client.search_with_query(index_name='document',  query = 'Türkiye odalar', top_k = 3)
# Out:
# [{'content': 'No:87/7 İskitler - Ankara Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr III Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr ÖNSÖZ Türkiye Odalar ve Borsalar Birliği (TOBB), Türk özel sektörünün en üst düzey yasal temsilcisi sıfatı ile iş dünyasının ihtiyaçları doğrultusunda çalışmalar yürütmekte, sorunlarına çözüm aramakta ve özel sektörün istikrarlı bir biçimde gelişimine katkıda bulunmaktadır. Sektörlerimize daha kapsamlı hizmet sunulması ihtiyacı doğrultusunda ve bu hizmetlerin geliştirilmesi perspektifinde 18 Mayıs 2004 tarih ve 5174 sayılı Türkiye Odalar ve Borsalar Birliği ile Odalar ve Borsalar Kanunu’nun 57’nci maddesine dayanılarak “Türkiye Sektör Meclislerinin Kuruluş, Görev ve Çalışma Yönetmeliği” hazırlanmıştır.',
#   'content_type': 'text',
#   'id_hash_keys': ['content'],
#   '_split_id': 2,
#   'language': 'tr'},
# ...

# %%
client.get_all_ids(index_name='document')[8:10]
# Out:
# ['3446a0a66e1ac2a5d6e4dd4a544227b1', '7f374830e49844051e386fe832d484c6']

# %%
client.get_document_by_id(index_name='document',  doc_id ="3446a0a66e1ac2a5d6e4dd4a544227b1")
# Out:
# {'_index': 'document',
#  '_id': '3446a0a66e1ac2a5d6e4dd4a544227b1',
#  '_version': 1,
#  '_seq_no': 8,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'content': 'Tarım meclisimizin hazırladığı “Tarım Sektör Raporu 2012” sektörel politika ve stratejilerin oluşturulması, geleceğe yönelik projeksiyonlara ve pazar araştırmalarına katkıda bulunması açısından faydalı olacağı düşüncesi ile tarım sektörümüze, camiamıza ve ilgililere hayırlı olmasını dilerim. M. Rifat HİSARCIKLIOĞLU Başkan Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr V Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr İÇİNDEKİLER 1. TARIM SEKTÖRÜNÜN TÜRKİYE EKONOMİSİNDEKİ YERİ. .1 1.1. TEMEL GÖSTERGELER VE TARIMIN PAYI. .1 1.2. TARIM SEKTÖRÜNDEKİ İSTİHDAM.2 1.3. TARIM SEKTÖRÜNDE MESLEKİ EĞİTİM.2 1.4. TARIM SEKTÖRÜNDE ÜRETİM MİKTARLARI.3 1.4.1. TARLA ÜRÜNLERİ ÜRETİMİ.5 1.4.2. BAKLAGİLLER. .10 1.4.3. ENDÜSTRİ BİTKİLERİ. . 11 1.4.4.',
#   'content_type': 'text',
# ...

# %%
client.get_document_by_id(index_name='document',  doc_id ="7f374830e49844051e386fe832d484c6")
# Out:
# {'_index': 'document',
#  '_id': '7f374830e49844051e386fe832d484c6',
#  '_version': 1,
#  '_seq_no': 9,
#  '_primary_term': 1,
#  'found': True,
#  '_source': {'content': 'ENDÜSTRİ BİTKİLERİ. . 11 1.4.4. YAĞLI TOHUMLU BİTKİLER.12 1.4.5. MEYVECİLİK.14 1.4.6. SEBZECİLİK.17 1.4.7. TIBBİ VE ARAMOTİK BİTKİLER.19 1.4.8. SÜS BİTKİLERİ. .21 2. YATIRIM ORTAMININ İYİLEŞTİRİLMESİ İLE BÖLGESEL TEŞVİK VE YARDIMLAR.25 2.1. TARIM SEKTÖRÜNÜN YATIRIM ORTAMI.25 2.2. TARIM SEKTÖRÜNDE ALTYAPI VE ÜSTYAPIYA İLİŞKİN İHTİYAÇLAR.26 2.2.1. STRATEJİK BELGELER.28 2.2.2. YATIRIM TEŞVİKLERİ.28 2.2.3. TARIMSAL DESTEKLER.34 3. SEKTÖRDE YENİ YÖNELİMLER.39 3.1. SEKTÖRDE TEKNOLOJİ KULLANIM DÜZEYİ.39 3.1.1. ÖRTÜ ALTI YETİŞTİRİCİLİĞİ.42 3.1.2. ORGANİK TARIM.42 3.1.3. İYİ TARIM UYGULAMALARI.44 3.1.4. BİYOTEKNOLOJİ.45 3.1.5. FİDE- FİDAN VE TOHUM.46 3.1.6. LİSANSLI DEPOCULUK.52 3.2. YENİ TEKNOLOJİLERİN BENİMSENMESİ VE KULLANILMASI,.54 3.2.1.',
#   'content_type': 'text',
#   'id_hash_keys': ['content'],
# ...

# %%
# See the structure of the object.

#  _id: assigned by elasticsearch
# _index: also assigned.
# _source: is the item we pushed.

# %% [markdown]
# # Test NER Updater

# %%
from utils.NamedEntityUpdater import NamedEntityUpdater

named_entity_updater = NamedEntityUpdater(ner_model_english= "dslim/bert-base-NER", 
                                          ner_model_turkish= "savasy/bert-base-turkish-ner-cased")

document_store = client.get_document_store()

# %%
document_store.get_document_by_id(index="document", id="3446a0a66e1ac2a5d6e4dd4a544227b1")
# Out:
# <Document: {'content': 'Tarım meclisimizin hazırladığı “Tarım Sektör Raporu 2012” sektörel politika ve stratejilerin oluşturulması, geleceğe yönelik projeksiyonlara ve pazar araştırmalarına katkıda bulunması açısından faydalı olacağı düşüncesi ile tarım sektörümüze, camiamıza ve ilgililere hayırlı olmasını dilerim. M. Rifat HİSARCIKLIOĞLU Başkan Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr V Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr İÇİNDEKİLER 1. TARIM SEKTÖRÜNÜN TÜRKİYE EKONOMİSİNDEKİ YERİ. .1 1.1. TEMEL GÖSTERGELER VE TARIMIN PAYI. .1 1.2. TARIM SEKTÖRÜNDEKİ İSTİHDAM.2 1.3. TARIM SEKTÖRÜNDE MESLEKİ EĞİTİM.2 1.4. TARIM SEKTÖRÜNDE ÜRETİM MİKTARLARI.3 1.4.1. TARLA ÜRÜNLERİ ÜRETİMİ.5 1.4.2. BAKLAGİLLER. .10 1.4.3. ENDÜSTRİ BİTKİLERİ. . 11 1.4.4.', 'content_type': 'text', 'score': 0.5312093733737563, 'meta': {'_split_id': 8, 'language': 'tr'}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '3446a0a66e1ac2a5d6e4dd4a544227b1'}>

# %%
test_doc = client.get_document_by_id(index_name='document',  doc_id ="3446a0a66e1ac2a5d6e4dd4a544227b1")

# %%
test_doc["_source"]["language"]
# Out:
# 'tr'

# %%
docs_list = [


{'_index': 'document',
 '_id': '7f374830e49844051e386fe832d484c6',
 '_version': 1,
 '_seq_no': 9,
 '_primary_term': 1,
 'found': True,
 '_source': {'content': 'ENDÜSTRİ BİTKİLERİ. . 11 1.4.4. YAĞLI TOHUMLU BİTKİLER.12 1.4.5. MEYVECİLİK.14 1.4.6. SEBZECİLİK.17 1.4.7. TIBBİ VE ARAMOTİK BİTKİLER.19 1.4.8. SÜS BİTKİLERİ. .21 2. YATIRIM ORTAMININ İYİLEŞTİRİLMESİ İLE BÖLGESEL TEŞVİK VE YARDIMLAR.25 2.1. TARIM SEKTÖRÜNÜN YATIRIM ORTAMI.25 2.2. TARIM SEKTÖRÜNDE ALTYAPI VE ÜSTYAPIYA İLİŞKİN İHTİYAÇLAR.26 2.2.1. STRATEJİK BELGELER.28 2.2.2. YATIRIM TEŞVİKLERİ.28 2.2.3. TARIMSAL DESTEKLER.34 3. SEKTÖRDE YENİ YÖNELİMLER.39 3.1. SEKTÖRDE TEKNOLOJİ KULLANIM DÜZEYİ.39 3.1.1. ÖRTÜ ALTI YETİŞTİRİCİLİĞİ.42 3.1.2. ORGANİK TARIM.42 3.1.3. İYİ TARIM UYGULAMALARI.44 3.1.4. BİYOTEKNOLOJİ.45 3.1.5. FİDE- FİDAN VE TOHUM.46 3.1.6. LİSANSLI DEPOCULUK.52 3.2. YENİ TEKNOLOJİLERİN BENİMSENMESİ VE KULLANILMASI,.54 3.2.1.',
  'content_type': 'text',
  'id_hash_keys': ['content'],
  '_split_id': 9,
  'language': 'tr'}},
    
    
    {'_index': 'document',
 '_id': '3446a0a66e1ac2a5d6e4dd4a544227b1',
 '_version': 1,
 '_seq_no': 8,
 '_primary_term': 1,
 'found': True,
 '_source': {'content': 'Tarım meclisimizin hazırladığı “Tarım Sektör Raporu 2012” sektörel politika ve stratejilerin oluşturulması, geleceğe yönelik projeksiyonlara ve pazar araştırmalarına katkıda bulunması açısından faydalı olacağı düşüncesi ile tarım sektörümüze, camiamıza ve ilgililere hayırlı olmasını dilerim. M. Rifat HİSARCIKLIOĞLU Başkan Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr V Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr İÇİNDEKİLER 1. TARIM SEKTÖRÜNÜN TÜRKİYE EKONOMİSİNDEKİ YERİ. .1 1.1. TEMEL GÖSTERGELER VE TARIMIN PAYI. .1 1.2. TARIM SEKTÖRÜNDEKİ İSTİHDAM.2 1.3. TARIM SEKTÖRÜNDE MESLEKİ EĞİTİM.2 1.4. TARIM SEKTÖRÜNDE ÜRETİM MİKTARLARI.3 1.4.1. TARLA ÜRÜNLERİ ÜRETİMİ.5 1.4.2. BAKLAGİLLER. .10 1.4.3. ENDÜSTRİ BİTKİLERİ. . 11 1.4.4.',
  'content_type': 'text',
  'id_hash_keys': ['content'],
  '_split_id': 8,
  'language': 'tr'}}


]


out = named_entity_updater.update_documents(docs_list)
# Out:
# Extracting entities:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
out
# Out:
# [{'entity_group': 'ORG',
#   'score': 0.8030975,
#   'word': 'FİDE',
#   'start': 626,
#   'end': 630}]

# %% [markdown]
# # Test Retriever

# %%
from utils.semanticSearch import BM25PassageRetriever

# %%
document_store = client.get_document_store()
BM25PassageRetriever = BM25PassageRetriever(document_store)

# %%
BM25PassageRetriever.retrieve_passages("sektör dinamikleri", top_k = 3)
# Out:
# [<Document: {'content': 'Ayrıca bu politikaların oluşturulmasında, sadece ilgili uzmanların değil, faydalanıcıların da görüşleri alınmak suretiyle ülkemizin biyolojik çeşitliliğinin ve bitki gen kaynaklarının korunmasının yanı sıra bitki ıslahçılarının bu materyale, birçok ülkede olduğu gibi kolayca erişiminin sağlanmasının da altyapısı oluşturulma- lıdır. Endüstri alanında her iş kolu için ortak olan çeşitli dinamikler olduğu gibi her bir endüstriyel faaliyetin kendine özgü olan iç ve dış dinamikleri de söz konusudur. Diğer sektörlerde olduğu gibi tohumculuk endüstrisinde de bu dinamiklerin tanımlanmasına ve sektörün analiz edilebilmesine ihtiyaç duyulmaktadır. Fide sektöründe ise halen 110 fide işletmesi bulunmaktadır. Bu işletmelerin 2012 yılı sonu itibariyle 87’si FİDEBİRLİK’e üye olarak kayıtlıdır.', 'content_type': 'text', 'score': 0.6733866387016691, 'meta': {'_split_id': 222, 'language': 'tr'}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a430bc51e22d2f7d0c59f5f5302
# ...

# %% [markdown]
# # Test Summarizer

# %%
from utils.SummaryUpdater import DocumentSummarizer
# Out:
# OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# WARNING:haystack.nodes.answer_generator.openai:OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.

# %%
from haystack.nodes import TransformersSummarizer
from haystack import Document

docs = [Document("""
Türkiye’de yeni oluşturulan yatırım teşvik sistemi ile, ülkenin stratejik sektörleri için önem arz
eden ara mallara olan ithalat bağımlılığını azaltma potansiyeli taşıyan yatırımları teşvik etmek
amaçlanmıştır. Cari açığın kapatılması, en az gelişmiş bölgelere sağlanan yatırım desteklerinin
genişletilmesi, destek unsuru miktarlarının artırılması, kümelenme faaliyetlerinin teşvik edilmesi,
teknoloji dönüşümü sağlayacak yatırımların desteklenmesi yeni yatırım teşvik sisteminin temel
amaçları arasında yer almaktadır. Yatırım kararlarını hızlandırmak amacıyla, yeni yatırım teşvik
sistemi 2013 yılı sonu itibarıyla gerçekleştirilecek yatırımlar için daha avantajlı destekler sunmaktadır.
Yatırım tutarının en az % 10’unun gerçekleştirilmesi, yatırımın başlamış olarak kabul edilmesi
için yeterli olacaktır. Yatırım teşvik sistemi dört ayrı rejimden oluşmaktadır. Yerli ve yabancı yatırımcılar,
aşağıdaki teşviklerden eşit oranda faydalanabilmektedir:""")]

summarizer = TransformersSummarizer(model_name_or_path="ozcangundes/mt5-small-turkish-summarization", max_length=200,
             min_length= 10)
# Out:
# C:\Users\ersin\KOD\haystack\venv\lib\site-packages\transformers\convert_slow_tokenizer.py:447: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   "The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option"

# %%
summary = summarizer.predict(documents=docs)
summary
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ...

# %%
docs = [Document("""
G.T.İ.P. numarasına göre Temel Kimyasallar Sektörü Haziran 2020 - 2021 ihracatını karşılaştırdığımızda 2020 yılında 155,7 milyon dolar ihracat gerçekleştirildiği, 2021 yılında ise ihracatın, önceki yıla göre %71 oranında artarak 266,4 milyon dolar olarak gerçekleştirildiği gözlemlenmektedir.
2020 Haziran ihracat rakamları ile karşılaştırıldığında; 2021 Haziran’ da 151 ürün grubu %100’ ün üzerinde artış göstermiştir. En çok artış gösteren ilk 5 GTİP 290539959019 - Dioller – Diğer, 291639909019 - Diğerleri, 290517002012 - Stearil Alkol, 283719009012 - Bakır Siyanürler Ve 291614000019 - Metakrilik Asitin Diğer Esterleri olmuştur.
2020 Haziran’ da ihracat yapılan 290243000000 - P – Ksilen, 291712000011 - Adipik Asit, 294110000034 - Sultamycillin Tosylat, 283529902000 - Sodyum Fosfatlar, 284190853019 - Diğer Aluminatlar ve 291570409011 - Sodyum Palmitat gibi 116 ürün grubunda 2021 Haziran’ da ihracat gerçekleşmemiştir.
2020 Haziran ihracatında ilk 3 ürün grubu 283620000011 - Susuz Sodyum Karbonat (Dehidrate), 284019100000 - Disodyum Tetraborat Pentahidrat, 283630000000 - Sodyum Hidrojen Karbonat Sodyum Bikarbonat (Karbonat) olurken; 2021 Haziran ihracatında ise ilk 3 sırada 283620000011 - Susuz Sodyum Karbonat (Dehidrate), 284019100000 - 
Disodyum Tetraborat Pentahidrat ve 281000909011 - Orto Borik Asit (Borik Asit) yer almaktadır.""")]

summary = summarizer.predict(documents=docs)
summary
# Out:
# [<Document: {'content': '\nG.T.İ.P. numarasına göre Temel Kimyasallar Sektörü Haziran 2020 - 2021 ihracatını karşılaştırdığımızda 2020 yılında 155,7 milyon dolar ihracat gerçekleştirildiği, 2021 yılında ise ihracatın, önceki yıla göre %71 oranında artarak 266,4 milyon dolar olarak gerçekleştirildiği gözlemlenmektedir.\n2020 Haziran ihracat rakamları ile karşılaştırıldığında; 2021 Haziran’ da 151 ürün grubu %100’ ün üzerinde artış göstermiştir. En çok artış gösteren ilk 5 GTİP 290539959019 - Dioller – Diğer, 291639909019 - Diğerleri, 290517002012 - Stearil Alkol, 283719009012 - Bakır Siyanürler Ve 291614000019 - Metakrilik Asitin Diğer Esterleri olmuştur.\n2020 Haziran’ da ihracat yapılan 290243000000 - P – Ksilen, 291712000011 - Adipik Asit, 294110000034 - Sultamycillin Tosylat, 283529902000 - Sodyum Fosfatlar, 284190853019 - Diğer Aluminatlar ve 291570409011 - Sodyum Palmitat gibi 116 ürün grubunda 2021 Haziran’ da ihracat gerçekleşmemiştir.\n2020 Haziran ihracatında ilk 3 ürün grub
# ...

# %%
# Works nicely, no need to setup GPU environment. But High CPU preferred.

# %% [markdown]
# # QA-OpenAI

# %%
# Question Answering pipeline, but uses openai to answer it.

# %%
from utils.QuestionAnswering_gpt import AnswerGenerator

from utils.elasticClient import ElasticClient

# Replace with your actual host, port, username, and password
host = "elastic-ede4ac.es.us-central1.gcp.cloud.es.io"
port = 9243
username = "elastic"
password = "iQR2A4PZiIsE0XO7BZ11hH5R"

# Initialize the ElasticClient
client = ElasticClient(host=host, port=port, username=username, password=password)

document_store = client.get_document_store()
api_key = "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"
top_k = 3
model = "text-ada-001"  #"text-davinci-003" # DaVinci Çok daha iyi çalışıyor. Customizable olmalı.


AnswerGenerator = AnswerGenerator(model = model, document_store = document_store, api_key = api_key, top_k = top_k)

# %%
query = "OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek ne kadardır?"
answer = AnswerGenerator.generate_answer(query=query)
answer
# Out:
# WARNING:haystack.nodes.prompt.prompt_node:1 out of the 1 completions have been truncated before reaching a natural stopping point.Consider increasing the max_tokens parameter to allow for longer completions.
# {'results': ['OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek ise Türkiye’de ise yüzde 22, ABD’de yüzde 12, İsraelinde yüzde 12, Kanada ise yüzde 16 seviyesindedir. Dünyada yaşanan ekonomik krizler tarı'],
#  'invocation_context': {'query': 'OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek ne kadardır?',
# ...

# %% [markdown]
# # QA - Reader

# %%
# QA pipeline, uses transformers from huggingface.

# %%
from utils.QuestionAnswering_reader import AnswerGeneratorReader

from utils.elasticClient import ElasticClient

# Replace with your actual host, port, username, and password
host = "elastic-ede4ac.es.us-central1.gcp.cloud.es.io"
port = 9243
username = "elastic"
password = "iQR2A4PZiIsE0XO7BZ11hH5R"

# Initialize the ElasticClient
client = ElasticClient(host=host, port=port, username=username, password=password)

document_store = client.get_document_store()
top_k = 3

AnswerGenerator = AnswerGeneratorReader(document_store = document_store, top_k = top_k)

# %%
query = "OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek ne kadardır?"
answer = AnswerGenerator.generate_answer(query=query) # Reader based one gave better answers.
answer
# Out:
# {'query': 'OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek ne kadardır?',
#  'answers': [<Answer {'answer': '980 milyona', 'type': 'extractive', 'score': 0.9996477365493774, 'context': 'tur. 2009 yılında 2,5 milyar olan kesme çiçek üretiminin 2010 yılında 980 milyona düşmesi sektörün ekonomik krizlerle ilişkisinin ne kadar yakın olduğu', 'offsets_in_document': [{'start': 254, 'end': 265}], 'offsets_in_context': [{'start': 70, 'end': 81}], 'document_ids': ['af144199303248278e336e52a937b5a2'], 'meta': {'_split_id': 35, 'language': 'tr'}}>,
# ...

# %% [markdown]
# # Search Summarizer

# %%
# Name arama yapınca adı geçen tüm textler toplanıp özetlenir. Gerek olmayabilir.

# %%
from utils.searchSummarizer import SummaryGenerator

from utils.elasticClient import ElasticClient

# Replace with your actual host, port, username, and password
host = "elastic-ede4ac.es.us-central1.gcp.cloud.es.io"
port = 9243
username = "elastic"
password = "iQR2A4PZiIsE0XO7BZ11hH5R"

# Initialize the ElasticClient
client = ElasticClient(host=host, port=port, username=username, password=password)

document_store = client.get_document_store()
top_k = 3
model="ozcangundes/mt5-small-turkish-summarization"
SummaryGenerator = SummaryGenerator(model=model,document_store=document_store)
# Out:
# OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# WARNING:haystack.nodes.answer_generator.openai:OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# C:\Users\ersin\KOD\haystack\venv\lib\site-packages\transformers\convert_slow_tokenizer.py:447: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   "The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option"

# %%
query = "OECD’ye üye ülkelerde tarım sektörüne yapılan destek oranı"
summary = SummaryGenerator.generate_summary(query=query)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
summary
# Out:
# {'documents': [<Document: {'content': '2004 yılında destekleme bütçesinin yüzde 11’ini oluşturan fark ödemesi destekle- melerinin, 2011 yılındaki payı yüzde 33,4 olup, 30 tarım havzası temelinde uygulanmasına devam edilmektedir. Türkiye Tarım Sektörü Raporu 2013 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr 35 Türkiye Odalar ve Borsalar Birliği / www.tobb.org.tr OECD’ye üye ülkelerde tarım sektörüne yapılan destek oranı azalırken, sadece Türkiye’de bu oran artış göstermiştir. OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek rekor seviyede düşerek 227 milyar ABD Doları’na gerilemiş ve tarım sektörüne yapılan destekler 1980’li yıllardan bu yana en düşük seviyeye inmiştir. OECD ülkelerinde 2010 yılında tarım sektörüne verilen destek rekor seviyede düşerek 227 milyar ABD Doları’na gerilemiş ve tarım sektörüne yapılan destekler 1980’li yıllardan bu yana en düşük seviyeye inmiştir. Türkiye’de, 1986–1988 yıllarında yüzde 20 olan tarım sektörüne destek, 2008–2010 yıllarınd
# ...

# %%
query = "Teknoloji geliştirme bölgelerine yapılan destekler"
summary = SummaryGenerator.generate_summary(query=query)

# %%
summary
# Out:
# {'documents': [<Document: {'content': 'Çünkü tohumculuk sektöründe bu kadar araştırıcı istihdam etmek gerekli olmadığı gibi, bunu karşılayacak özel sektör firması da yoktur.)2. Teknoloji Geliştirme Bölgelerine yönelik destekler Teknoloji Geliştirme Bölgelerine (TGB) sağlanan avantajlar; a) Kiralamaya hazır ofisler ve altyapı tesisleri sağlanmaktadır; b) Yazılım ve Ar-Ge faaliyetlerinden elde edilen kârlar 31.12.2023 tarihine kadar gelir ve kurumlar vergisinden muaftır; c) TGB içinde üretilen uygulama yazılımlarının satışı 31.12.2023 tarihine kadar KDV’den muaftır; d) TGB’lerde istihdam edilen araştırmacılar ile yazılım geliştirme ve Ar-Ge personeline ödenecek maaşlar 31.12.2023 tarihine kadar kişisel gelir vergisinden muaftır; e) 31.12.2024 tarihine kadar beş yıl boyunca SGK primi işveren payının % 50’si devlet tarafından karşılanacaktır. Teknoloji Geliştirme Bölgelerine yönelik destekler Teknoloji Geliştirme Bölgelerine (TGB) sağlanan avantajlar; a) Kiralamaya hazır ofisler ve altya
# ...

# %% [markdown]
# # Unified QA Class

# %%
from utils.QuestionAnswering import AnswerGeneratorUnified
# Out:
# OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# WARNING:haystack.nodes.answer_generator.openai:OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.

# %%
from utils.elasticClient import ElasticClient

# Replace with your actual host, port, username, and password
host = "elastic-ede4ac.es.us-central1.gcp.cloud.es.io"
port = 9243
username = "elastic"
password = "iQR2A4PZiIsE0XO7BZ11hH5R"

# Initialize the ElasticClient
client = ElasticClient(host=host, port=port, username=username, password=password)

document_store = client.get_document_store()
top_k = 3
model = "text-ada-001" 
api_key = "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"


AnswerGenerator = AnswerGeneratorUnified(model = model, api_key = api_key, document_store = document_store, top_k = top_k)

# %%
query = "Teknoloji geliştirme bölgelerine yapılan destekler"
AnswerGenerator.generate_answer_reader(query)
# Out:
# {'query': 'Teknoloji geliştirme bölgelerine yapılan destekler',
#  'answers': [<Answer {'answer': 'Kiralamaya hazır ofisler ve altyapı tesisleri sağlanmaktadır;', 'type': 'extractive', 'score': 0.22757041454315186, 'context': 'tekler Teknoloji Geliştirme Bölgelerine (TGB) sağlanan avantajlar; a) Kiralamaya hazır ofisler ve altyapı tesisleri sağlanmaktadır; b) Yazılım ve Ar-Ge faaliyetlerinden elde edilen kârlar 31.12.2023 ta', 'offsets_in_document': [{'start': 114, 'end': 175}], 'offsets_in_context': [{'start': 70, 'end': 131}], 'document_ids': ['78e1f9fe9299d6660ecb67ff36973831'], 'meta': {'_split_id': 259, 'language': 'tr'}}>,
# ...

# %%
AnswerGenerator.generate_answer_prompt(query)
# Out:
# {'results': ['Your answer should be in your own words and be no longer than 20 words.'],
#  'invocation_context': {'query': 'Teknoloji geliştirme bölgelerine yapılan destekler',
# ...

# %% [markdown]
# # TEXT TO KG?
